# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba7cb85d-a89e-4098-b583-248d3f5bffb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba7cb85d-a89e-4098-b583-248d3f5bffb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-f3bc24a0-1118-49c3-b003-40d11cddb5df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3bc24a0-1118-49c3-b003-40d11cddb5df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
 
df1 = pd.read_csv(io.BytesIO(uploaded['college_1.csv']))
print(df1)
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2 = pd.read_csv(io.BytesIO(uploaded1['college_2.csv']))
print(df2)
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
frames = [df1, df2]

df3 = pd.concat(frames)

df3
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %%
num_rows=df1.shape[0]
rows_per_file = 42
num_files = 1
for i in range(len(df1)):
  if i % 84 == 0:
    open(str(num_files) + '.csv', 'w+').writelines(df1[i:i+84])
    num_files += 1

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
a = []
#for i in df3:
for j in range(len(df3)):
  print(j,df3.iloc[j]['CodeKata Score'])
  if (int(df3.iloc[j]['CodeKata Score']) > 15000) is True:
    print(df3.iloc[0])
    a.append(df3.iloc[j])
print(a)
df_L1500 = pd.DataFrame(a)
print(df_L1500)
df_L1500.to_csv('Exceeded expectations.csv')
# Out:
# 0 24500
# Name                                             A.Dharani
# python                                                82.0
# mysql                                                 20.0
# Previous Geekions                                    24500
# CodeKata Score                                       24500
# Department                Computer Science and Engineering
# Rising                                                   0
# python_en                                              NaN
# computational_thinking                                 NaN
# Name: 0, dtype: object
# 1 21740
# Name                                             A.Dharani
# python                                                82.0
# mysql                                                 20.0
# Previous Geekions                                    24500
# CodeKata Score                                       24500
# Department                Computer Science and Engineering
# ...

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
a = []
#for i in df3:
for j in range(len(df3)):
  #print(j,df3.iloc[j]['CodeKata Score'])
  if ((10000 < int(df3.iloc[j]['CodeKata Score'])) and(int(df3.iloc[j]['CodeKata Score'])< 15000)) is True:
    #print(j, df3.iloc[j])
    a.append(df3.iloc[j])
df_L1500 = pd.DataFrame(a)
print(df_L1500)
df_L1500.to_csv('Reached_expectations.csv')
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
a = []
#for i in df3:
for j in range(len(df3)):
  #print(j,df3.iloc[j]['CodeKata Score'])
  if ((7000 < int(df3.iloc[j]['CodeKata Score'])) and(int(df3.iloc[j]['CodeKata Score'])< 10000)) is True:
    #print(j, df3.iloc[j])
    a.append(df3.iloc[j])
df_L1500 = pd.DataFrame(a)
print(df_L1500)
df_L1500.to_csv('Needs_Improvement.csv')
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S   100.0    8.0               8980            8980
# 5             NIVEESHWAR S   100.0    0.0               8200            8200
# 6            KALAIARASAN K    85.0   47.0               7750            7880
# 7     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
a = []
#for i in df3:
for j in range(len(df3)):
  #print(j,df3.iloc[j]['CodeKata Score'])
  if (7000 > int(df3.iloc[j]['CodeKata Score'])) is True:
    #print(j, df3.iloc[j])
    a.append(df3.iloc[j])
df_L1500 = pd.DataFrame(a)
print(df_L1500)
df_L1500.to_csv('Unsatisfactory.csv')
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j    24.0   0.00               2380            2380
# 31       AMARNATH D    -1.0  12.00               1890            1890
# 32             bala    32.0   0.00               1720            1720
# 33             XY Z    -1.0  -1.00                  0               0
# 34        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df3['avg'] = df3[['Previous Geekions', 'CodeKata Score']].mean(axis=1)
df3
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### No of students participated

# %%
df3['Name'].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df3['python'].mean()
# Out:
# 54.35294117647059

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
score = df3['Rising']
name = df3['Name']
a = sorted(zip(score, name), reverse=True)[:3]
print(*a,sep = '\n')
# Out:
# (3140, 'shifak N')
# (2000, 'Narasimhan Y L')
# (2000, 'Ganesh Ramkumar R')

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
score = df3['Previous Geekions']
name = df3['Name']
a = sorted(zip(score, name), reverse=True)[:3]
print(*a,sep = '\n')
# Out:
# (24500, 'A.Dharani')
# (21740, 'V.JEEVITHA ')
# (19680, 'HEMAVATHI.R')

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df3.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score')
# Out:
# <ipython-input-130-bb6ba1bdeebb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3.groupby(['Department']).sum().plot(kind='pie', y='CodeKata Score')
# <Axes: ylabel='CodeKata Score'>

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
import matplotlib.pyplot as plt
 
dept = df3['Department']
Score = df3['CodeKata Score']
x,y = sorted(zip(Score,dept), reverse=True)[:3]
print(x)
print(y)
plt.bar(x, y)
 
# setting x-label as pen sold
plt.xlabel("Department")
 
# setting y_label as price
plt.ylabel("Score")  
plt.title(" Vertical bar graph")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-5a1889a27994> in <cell line: 5>()
#       3 dept = df3['Department']
#       4 Score = df3['CodeKata Score']
# ----> 5 x,y = sorted(zip(Score,dept), reverse=True)[:3]
#       6 print(x)
#       7 print(y)
#
# ValueError: too many values to unpack (expected 2)
